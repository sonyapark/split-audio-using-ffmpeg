# %%
#you have to adjust x of "while (l <= x)" according to duration and music length 1.music length(second)/duration=y 2.duration*y ????
#if you want to change interval, change x of "j += x" and x of "l += x"
#if you want to change pianist, change x of "pianist = "x""
#smallest interval is 1 second

#if result is inaccurate, check audio length by using this command "mp3info -p " %f %m:%s\n" *.mp3"
import sys
import os
#pianist is pianist name(file name)
pianist = "suyeon"

#i means file number will be created
#j and l mean second
i = 0
j = 0
l = 0
while (j <= 59):
    all = ["ffmpeg -i ",str(pianist),".mp3 ","-ss 00:00:",str(j)," -t 00:00:5 data/duration5-interval3/",str(pianist),"_split/",str(pianist),"_",i,".mp3 ; "]
    #below 1,2 are inaccurate
    #1.all = ["ffmpeg -ss 00:00:",str(j)," -i ",str(pianist),".mp3 -t 00:00:5 -c:v libx264 -c:a aac -strict experimental -b:a 128k ",str(pianist),"_split/",str(pianist),"_",i,".mp3 ; "]
    #2.all = ["ffmpeg -ss 00:00:",str(j)," -i ",str(pianist),".mp3 -t 00:00:5 -c copy ",str(pianist),"_split/",str(pianist),"_",i,".mp3 ; "]
    sys.stdout.write(''.join(map(str, all)))  
    #print(''.join(map(str, all)))
    i += 1
    j += 3
    if j >= 60:
        k = i
        while (l <= 49):
            all_2 = ["ffmpeg -i ",str(pianist),".mp3 ","-ss 00:01:",str(l)," -t 00:00:5 data/duration5-interval3/",str(pianist),"_split/",str(pianist),"_",k,".mp3 ;"]
            sys.stdout.write(''.join(map(str, all_2)))  
            #print(''.join(map(str, all_2)))
            k += 1
            l += 3
# Out:
# ffmpeg -i suyeon.mp3 -ss 00:00:0 -t 00:00:5 data/duration5-interval3/suyeon_split/suyeon_0.mp3 ; ffmpeg -i suyeon.mp3 -ss 00:00:3 -t 00:00:5 data/duration5-interval3/suyeon_split/suyeon_1.mp3 ; ffmpeg -i suyeon.mp3 -ss 00:00:6 -t 00:00:5 data/duration5-interval3/suyeon_split/suyeon_2.mp3 ; ffmpeg -i suyeon.mp3 -ss 00:00:9 -t 00:00:5 data/duration5-interval3/suyeon_split/suyeon_3.mp3 ; ffmpeg -i suyeon.mp3 -ss 00:00:12 -t 00:00:5 data/duration5-interval3/suyeon_split/suyeon_4.mp3 ; ffmpeg -i suyeon.mp3 -ss 00:00:15 -t 00:00:5 data/duration5-interval3/suyeon_split/suyeon_5.mp3 ; ffmpeg -i suyeon.mp3 -ss 00:00:18 -t 00:00:5 data/duration5-interval3/suyeon_split/suyeon_6.mp3 ; ffmpeg -i suyeon.mp3 -ss 00:00:21 -t 00:00:5 data/duration5-interval3/suyeon_split/suyeon_7.mp3 ; ffmpeg -i suyeon.mp3 -ss 00:00:24 -t 00:00:5 data/duration5-interval3/suyeon_split/suyeon_8.mp3 ; ffmpeg -i suyeon.mp3 -ss 00:00:27 -t 00:00:5 data/duration5-interval3/suyeon_split/suyeon_9.mp3 ; ffmpeg -i suyeon.mp3 -
# ...

# %%
#you have to adjust x of "while (l <= x)" according to duration and music length (music length(s)-duration=x)
#if you want to change duration, change x of "duration = x"
#if you want to change interval, change x of "j += x" and x of "l += x"
#if you want to change pianist, change x of "pianist = "x""
#smallest interval is 1 second

#if result is inaccurate, check audio length by using this command "mp3info -p " %f %m:%s\n" *.mp3"
import sys
import os

#i means file number will be created
#j and l mean second
i = 0
j = 0
l = 0
duration = 20
while (j <= 59):
    #pianist is pianist name(file name)
    pianist = "suyeon"
    all = ["ffmpeg -i ",str(pianist),".mp3 ","-ss 00:00:",str(j)," -t 00:00:",str(duration)," data/duration",str(duration),"-interval3/",str(pianist),"_split/",str(pianist),"_",i,".mp3 ; "]
    #below 1,2 are inaccurate
    #1.all = ["ffmpeg -ss 00:00:",str(j)," -i ",str(pianist),".mp3 -t 00:00:5 -c:v libx264 -c:a aac -strict experimental -b:a 128k ",str(pianist),"_split/",str(pianist),"_",i,".mp3 ; "]
    #2.all = ["ffmpeg -ss 00:00:",str(j)," -i ",str(pianist),".mp3 -t 00:00:5 -c copy ",str(pianist),"_split/",str(pianist),"_",i,".mp3 ; "]
    sys.stdout.write(''.join(map(str, all)))  
    #print(''.join(map(str, all)))
    i += 1
    j += 3
    if j >= 60:
        k = i
        while (l <= 34):
            all_2 = ["ffmpeg -i ",str(pianist),".mp3 ","-ss 00:01:",str(l)," -t 00:00:",str(duration)," data/duration",str(duration),"-interval3/",str(pianist),"_split/",str(pianist),"_",k,".mp3 ;"]
            sys.stdout.write(''.join(map(str, all_2)))  
            #print(''.join(map(str, all_2)))
            k += 1
            l += 3
            

i = 0
j = 0
l = 0
while (j <= 59):
    #pianist is pianist name(file name)
    pianist = "alukasz"
    all = ["ffmpeg -i ",str(pianist),".mp3 ","-ss 00:00:",str(j)," -t 00:00:",str(duration)," data/duration",str(duration),"-interval3/",str(pianist),"_split/",str(pianist),"_",i,".mp3 ; "]
    #below 1,2 are inaccurate
    #1.all = ["ffmpeg -ss 00:00:",str(j)," -i ",str(pianist),".mp3 -t 00:00:5 -c:v libx264 -c:a aac -strict experimental -b:a 128k ",str(pianist),"_split/",str(pianist),"_",i,".mp3 ; "]
    #2.all = ["ffmpeg -ss 00:00:",str(j)," -i ",str(pianist),".mp3 -t 00:00:5 -c copy ",str(pianist),"_split/",str(pianist),"_",i,".mp3 ; "]
    sys.stdout.write(''.join(map(str, all)))  
    #print(''.join(map(str, all)))
    i += 1
    j += 3
    if j >= 60:
        k = i
        while (l <= 34):
            all_2 = ["ffmpeg -i ",str(pianist),".mp3 ","-ss 00:01:",str(l)," -t 00:00:",str(duration)," data/duration",str(duration),"-interval3/",str(pianist),"_split/",str(pianist),"_",k,".mp3 ;"]
            sys.stdout.write(''.join(map(str, all_2)))  
            #print(''.join(map(str, all_2)))
            k += 1
            l += 3
            

i = 0
j = 0
l = 0
k = 0
while (j <= 59):
    #pianist is pianist name(file name)
    pianist = "aimi"
    all = ["ffmpeg -i ",str(pianist),".mp3 ","-ss 00:00:",str(j)," -t 00:00:",str(duration)," data/duration",str(duration),"-interval3/",str(pianist),"_split/",str(pianist),"_",i,".mp3 ; "]
    #below 1,2 are inaccurate
    #1.all = ["ffmpeg -ss 00:00:",str(j)," -i ",str(pianist),".mp3 -t 00:00:5 -c:v libx264 -c:a aac -strict experimental -b:a 128k ",str(pianist),"_split/",str(pianist),"_",i,".mp3 ; "]
    #2.all = ["ffmpeg -ss 00:00:",str(j)," -i ",str(pianist),".mp3 -t 00:00:5 -c copy ",str(pianist),"_split/",str(pianist),"_",i,".mp3 ; "]
    sys.stdout.write(''.join(map(str, all)))  
    #print(''.join(map(str, all)))
    i += 1
    j += 3
    if j >= 60:
        k = i
        while (l <= 34):
            all_2 = ["ffmpeg -i ",str(pianist),".mp3 ","-ss 00:01:",str(l)," -t 00:00:",str(duration)," data/duration",str(duration),"-interval3/",str(pianist),"_split/",str(pianist),"_",k,".mp3 ;"]
            sys.stdout.write(''.join(map(str, all_2)))  
            #print(''.join(map(str, all_2)))
            k += 1
            l += 3
            
            

i = 0
j = 0
l = 0
k = 0
while (j <= 59):
    #pianist is pianist name(file name)
    pianist = "alixia"
    all = ["ffmpeg -i ",str(pianist),".mp3 ","-ss 00:00:",str(j)," -t 00:00:",str(duration)," data/duration",str(duration),"-interval3/",str(pianist),"_split/",str(pianist),"_",i,".mp3 ; "]
    #below 1,2 are inaccurate
    #1.all = ["ffmpeg -ss 00:00:",str(j)," -i ",str(pianist),".mp3 -t 00:00:5 -c:v libx264 -c:a aac -strict experimental -b:a 128k ",str(pianist),"_split/",str(pianist),"_",i,".mp3 ; "]
    #2.all = ["ffmpeg -ss 00:00:",str(j)," -i ",str(pianist),".mp3 -t 00:00:5 -c copy ",str(pianist),"_split/",str(pianist),"_",i,".mp3 ; "]
    sys.stdout.write(''.join(map(str, all)))  
    #print(''.join(map(str, all)))
    i += 1
    j += 3
    if j >= 60:
        k = i
        while (l <= 34):
            all_2 = ["ffmpeg -i ",str(pianist),".mp3 ","-ss 00:01:",str(l)," -t 00:00:",str(duration)," data/duration",str(duration),"-interval3/",str(pianist),"_split/",str(pianist),"_",k,".mp3 ;"]
            sys.stdout.write(''.join(map(str, all_2)))  
            #print(''.join(map(str, all_2)))
            k += 1
            l += 3
            
            

i = 0
j = 0
l = 0
k = 0
while (j <= 59):
    #pianist is pianist name(file name)
    pianist = "george"
    all = ["ffmpeg -i ",str(pianist),".mp3 ","-ss 00:00:",str(j)," -t 00:00:",str(duration)," data/duration",str(duration),"-interval3/",str(pianist),"_split/",str(pianist),"_",i,".mp3 ; "]
    #below 1,2 are inaccurate
    #1.all = ["ffmpeg -ss 00:00:",str(j)," -i ",str(pianist),".mp3 -t 00:00:5 -c:v libx264 -c:a aac -strict experimental -b:a 128k ",str(pianist),"_split/",str(pianist),"_",i,".mp3 ; "]
    #2.all = ["ffmpeg -ss 00:00:",str(j)," -i ",str(pianist),".mp3 -t 00:00:5 -c copy ",str(pianist),"_split/",str(pianist),"_",i,".mp3 ; "]
    #sys.stdout.write(''.join(map(str, all)))  
    print(''.join(map(str, all)))
    i += 1
    j += 9
    if j >= 60:
        k = i
        while (l <= 34):
            all_2 = ["ffmpeg -i ",str(pianist),".mp3 ","-ss 00:01:",str(l)," -t 00:00:",str(duration)," data/duration",str(duration),"-interval3/",str(pianist),"_split/",str(pianist),"_",k,".mp3 ;"]
            #sys.stdout.write(''.join(map(str, all_2)))  
            print(''.join(map(str, all_2)))
            k += 1
            l += 9

# %%
#you have to adjust x of "while (l <= x)" according to duration and music length 1.music length(second)/duration=y 2.duration*y ????
#if you want to change interval, change x of "j += x" and x of "l += x"
#if you want to change pianist, change x of "pianist = "x""
#smallest interval is 1 second

#suyeon, aimi, alexia, alukasz, george, nathalia

#if result is inaccurate, check audio length by using this command "mp3info -p " %f %m:%s\n" *.mp3"
import sys
import os
#pianist is pianist name(file name)

duration = 3

outpath_turtleneck="mp3files/data/datanumdifferent-durationdifferent/duration"+str(duration)+"-interval0-datanum10/turtleneck/"
outpath_correctposture="mp3files/data/datanumdifferent-durationdifferent/duration"+str(duration)+"-interval0-datanum10/correctposture/"

if not os.path.exists(outpath_turtleneck):
    os.mkdir( outpath_turtleneck, 0755 )
        
if not os.path.exists(outpath_correctposture):
    os.mkdir( outpath_correctposture, 0755 )
#i means file number will be created
#j and l mean second


pianists_correctposture = ["alukasz", "george"]
pianists_turtleneck = ["suyeon", "aimi", "alexia", "nathalia"]

pianists_i = 0
while pianists_i < len(pianists_correctposture):
    i = 0
    j = 0
    k = 0
    while (j <= 59):
        all = ["ffmpeg -i original/convert-in-samespeed_120second/",str(pianists_correctposture[pianists_i]),".mp3 ","-ss 00:00:",str(j)," -t 00:00:",duration," ",str(outpath_correctposture),str(pianists_correctposture[pianists_i]),"_",i,".mp3 ; "]
        sys.stdout.write(''.join(map(str, all)))  
        #print(''.join(map(str, all)))
        i += 1
        j += duration
        
        if j >= 60:
            k = i
            l = 0
            while (l <= 57):
                all2 = ["ffmpeg -i original/convert-in-samespeed_120second/",str(pianists_correctposture[pianists_i]),".mp3 ","-ss 00:01:",str(l)," -t 00:00:",duration," ",str(outpath_correctposture),str(pianists_correctposture[pianists_i]),"_",k,".mp3 ; "]
                sys.stdout.write(''.join(map(str, all2)))  
                #print(''.join(map(str, all2)))
                k += 1
                l += duration
    pianists_i += 1
    
pianists_i = 0
while pianists_i < len(pianists_turtleneck):
    i = 0
    j = 0
    k = 0
    while (j <= 59):
        all = ["ffmpeg -i original/convert-in-samespeed_120second/",str(pianists_turtleneck[pianists_i]),".mp3 ","-ss 00:00:",str(j)," -t 00:00:",duration," ",str(outpath_turtleneck),str(pianists_turtleneck[pianists_i]),"_",i,".mp3 ; "]
        sys.stdout.write(''.join(map(str, all)))  
        #print(''.join(map(str, all)))
        i += 1
        j += duration
        
        if j >= 60:
            k = i
            l = 0
            while (l <= 57):
                all2 = ["ffmpeg -i original/convert-in-samespeed_120second/",str(pianists_turtleneck[pianists_i]),".mp3 ","-ss 00:01:",str(l)," -t 00:00:",duration," ",str(outpath_turtleneck),str(pianists_turtleneck[pianists_i]),"_",k,".mp3 ; "]
                sys.stdout.write(''.join(map(str, all2)))  
                #print(''.join(map(str, all2)))
                k += 1
                l += duration
    pianists_i += 1
# Out:
# ffmpeg -i original/convert-in-samespeed_120second/alukasz.mp3 -ss 00:00:0 -t 00:00:3 mp3files/data/datanumdifferent-durationdifferent/duration3-interval0-datanum10/correctposture/alukasz_0.mp3 ; ffmpeg -i original/convert-in-samespeed_120second/alukasz.mp3 -ss 00:00:3 -t 00:00:3 mp3files/data/datanumdifferent-durationdifferent/duration3-interval0-datanum10/correctposture/alukasz_1.mp3 ; ffmpeg -i original/convert-in-samespeed_120second/alukasz.mp3 -ss 00:00:6 -t 00:00:3 mp3files/data/datanumdifferent-durationdifferent/duration3-interval0-datanum10/correctposture/alukasz_2.mp3 ; ffmpeg -i original/convert-in-samespeed_120second/alukasz.mp3 -ss 00:00:9 -t 00:00:3 mp3files/data/datanumdifferent-durationdifferent/duration3-interval0-datanum10/correctposture/alukasz_3.mp3 ; ffmpeg -i original/convert-in-samespeed_120second/alukasz.mp3 -ss 00:00:12 -t 00:00:3 mp3files/data/datanumdifferent-durationdifferent/duration3-interval0-datanum10/correctposture/alukasz_4.mp3 ; ffmpeg -i original/con
# ...

# %%
#you have to adjust x of "while (l <= x)" according to duration and music length 1.music length(second)/duration=y 2.duration*y ????
#if you want to change interval, change x of "j += x" and x of "l += x"
#if you want to change pianist, change x of "pianist = "x""
#smallest interval is 1 second

#suyeon, aimi, alexia, alukasz, george, nathalia

#if result is inaccurate, check audio length by using this command "mp3info -p " %f %m:%s\n" *.mp3"
import sys
import os
#pianist is pianist name(file name)

duration = 5

outpath_turtleneck="mp3files/data/samepianist-differentposture/"
outpath_correctposture="mp3files/data/samepianist-differentposture/"

if not os.path.exists(outpath_turtleneck):
    os.mkdir( outpath_turtleneck, 0755 )
        
if not os.path.exists(outpath_correctposture):
    os.mkdir( outpath_correctposture, 0755 )
#i means file number will be created
#j and l mean second


i = 0
j = 0
k = 0
while (j <= 59):
    all = ["ffmpeg -i original/samepianist-differentposture/","cmajor-incorrect-all.avi ","-ss 00:00:",str(j)," -t 00:00:",duration," ",i,".avi ; "]
    sys.stdout.write(''.join(map(str, all)))  
    #print(''.join(map(str, all)))
    i += 1
    j += duration
        
    if j >= 60:
        k = i
        l = 0
        while (l <= 57):
            all2 = ["ffmpeg -i original/samepianist-differentposture/","cmajor-incorrect-all.avi ","-ss 00:01:",str(l)," -t 00:00:",duration," ",k,".avi ; "]
            sys.stdout.write(''.join(map(str, all2)))  
            #print(''.join(map(str, all2)))
            k += 1
            l += duration
pianists_i += 1
# Out:
# ffmpeg -i original/samepianist-differentposture/cmajor-incorrect-all.avi -ss 00:00:0 -t 00:00:5 0.avi ; ffmpeg -i original/samepianist-differentposture/cmajor-incorrect-all.avi -ss 00:00:5 -t 00:00:5 1.avi ; ffmpeg -i original/samepianist-differentposture/cmajor-incorrect-all.avi -ss 00:00:10 -t 00:00:5 2.avi ; ffmpeg -i original/samepianist-differentposture/cmajor-incorrect-all.avi -ss 00:00:15 -t 00:00:5 3.avi ; ffmpeg -i original/samepianist-differentposture/cmajor-incorrect-all.avi -ss 00:00:20 -t 00:00:5 4.avi ; ffmpeg -i original/samepianist-differentposture/cmajor-incorrect-all.avi -ss 00:00:25 -t 00:00:5 5.avi ; ffmpeg -i original/samepianist-differentposture/cmajor-incorrect-all.avi -ss 00:00:30 -t 00:00:5 6.avi ; ffmpeg -i original/samepianist-differentposture/cmajor-incorrect-all.avi -ss 00:00:35 -t 00:00:5 7.avi ; ffmpeg -i original/samepianist-differentposture/cmajor-incorrect-all.avi -ss 00:00:40 -t 00:00:5 8.avi ; ffmpeg -i original/samepianist-differentposture/cmajor-
# ...
